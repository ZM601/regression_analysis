# %%
# %reset -f

# %% [markdown]
# # load all packages

# %%
import matplotlib.pyplot as plt
import numpy             as np
import pandas            as pd
import statsmodels.api   as sm

# %% [markdown]
# # load data into Python

# %%
df = pd.read_csv("KIELMC.csv")

# %% [markdown]
# # check the head of your table

# %%
df.head()
# Out:
#    year  age  agesq  nbh   cbd  intst  lintst  price  rooms  area  ...  \
# 0  1978   48   2304    4  3000   1000  6.9078  60000      7  1660  ...
# 1  1978   83   6889    4  4000   1000  6.9078  40000      6  2612  ...
# 2  1978   58   3364    4  4000   1000  6.9078  34000      6  1144  ...
# 3  1978   11    121    4  4000   1000  6.9078  63900      5  1136  ...
# 4  1978   48   2304    4  4000   2000  7.6009  44000      5  1868  ...
#
#       lprice  y81     larea     lland  y81ldist   lintstsq  nearinc  y81nrinc  \
# 0  11.002100    0  7.414573  8.429017       0.0  47.717705        1         0
# 1  10.596635    0  7.867871  9.032409       0.0  47.717705        1         0
# 2  10.434115    0  7.042286  8.517193       0.0  47.717705        1         0
# 3  11.065075    0  7.035269  9.210340       0.0  47.717705        1         0
# 4  10.691945    0  7.532624  9.210340       0.0  57.773682        1         0
#
#     rprice    lrprice
# 0  60000.0  11.002100
# 1  40000.0  10.596635
# ...

# %% [markdown]
# # add constant term

# %%
df = sm.add_constant(df)

# %% [markdown]
# # check the summary statistics

# %%
df.describe()
# Out:
#        const         year         age         agesq         nbh           cbd  \
# count  321.0   321.000000  321.000000    321.000000  321.000000    321.000000
# mean     1.0  1979.327103   18.009346   1381.566978    2.208723  15822.429907
# std      0.0     1.492329   32.565845   4801.788757    2.164353   8967.106296
# min      1.0  1978.000000    0.000000      0.000000    0.000000   1000.000000
# 25%      1.0  1978.000000    0.000000      0.000000    0.000000   9000.000000
# 50%      1.0  1978.000000    4.000000     16.000000    2.000000  14000.000000
# 75%      1.0  1981.000000   22.000000    484.000000    4.000000  23000.000000
# max      1.0  1981.000000  189.000000  35721.000000    6.000000  35000.000000
#
#               intst      lintst          price       rooms  ...      lprice  \
# count    321.000000  321.000000     321.000000  321.000000  ...  321.000000
# mean   16442.367601    9.480513   96100.660436    6.585670  ...   11.378118
# ...

# %% [markdown]
# # check variable names

# %%
df.columns
# Out:
# Index(['const', 'year', 'age', 'agesq', 'nbh', 'cbd', 'intst', 'lintst',
#        'price', 'rooms', 'area', 'land', 'baths', 'dist', 'ldist', 'wind',
#        'lprice', 'y81', 'larea', 'lland', 'y81ldist', 'lintstsq', 'nearinc',
#        'y81nrinc', 'rprice', 'lrprice'],
#       dtype='object')

# %% [markdown]
# # (c)

# %%
X_1   = df[['const', 'y81', 'nearinc', 'y81nrinc']]
Y_1   = df[['lrprice']]
M1 = sm.OLS(Y_1, X_1, missing='drop')

OLS1 = M1.fit()
print(OLS1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                lrprice   R-squared:                       0.246
# Model:                            OLS   Adj. R-squared:                  0.239
# Method:                 Least Squares   F-statistic:                     34.47
# Date:                Mon, 10 May 2021   Prob (F-statistic):           2.62e-19
# Time:                        01:34:52   Log-Likelihood:                -105.68
# No. Observations:                 321   AIC:                             219.4
# Df Residuals:                     317   BIC:                             234.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.2854      0.031    369.839      0.000      11.225      11.345
# ...

# %% [markdown]
# # (e)

# %%
X_2 = df[['const', 'y81', 'ldist', 'y81ldist']]
Y_2 = df[['lprice']]
M2  = sm.OLS(Y_2, X_2, missing='drop')

OLS2 = M2.fit()
print(OLS2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 lprice   R-squared:                       0.396
# Model:                            OLS   Adj. R-squared:                  0.390
# Method:                 Least Squares   F-statistic:                     69.22
# Date:                Mon, 10 May 2021   Prob (F-statistic):           1.87e-34
# Time:                        01:34:52   Log-Likelihood:                -109.24
# No. Observations:                 321   AIC:                             226.5
# Df Residuals:                     317   BIC:                             241.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.0585      0.508     15.850      0.000       7.058       9.059
# ...

# %% [markdown]
# # (f)

# %%
X_3 = df[['const', 'y81', 'ldist', 'y81ldist', 'age', 'agesq',
          'rooms', 'baths', 'lintst', 'lland', 'larea']]
Y_3 = df[['lprice']]
M3  = sm.OLS(Y_3, X_3, missing='drop')

OLS3 = M3.fit()
print(OLS3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 lprice   R-squared:                       0.787
# Model:                            OLS   Adj. R-squared:                  0.780
# Method:                 Least Squares   F-statistic:                     114.6
# Date:                Mon, 10 May 2021   Prob (F-statistic):           7.73e-98
# Time:                        01:34:52   Log-Likelihood:                 58.114
# No. Observations:                 321   AIC:                            -94.23
# Df Residuals:                     310   BIC:                            -52.74
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.6739      0.502     15.300      0.000       6.687       8.661
# ...

# %%
# !rm -rf W8_Python.html
# !jupyter nbconvert --to html W8_Python.ipynb
# Out:
# [NbConvertApp] Converting notebook W8_Python.ipynb to html
# [NbConvertApp] Writing 604117 bytes to W8_Python.html
